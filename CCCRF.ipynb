# %%
import pandas as pd

# %%
from google.colab import files
import io
uploader = files.upload()
# Out:
#      <input type="file" id="files-c3e7d582-7dea-45a0-890b-4be9c3efb2f1" name="files[]" multiple disabled />
#      <output id="result-c3e7d582-7dea-45a0-890b-4be9c3efb2f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving communities.data to communities.data
# Saving attributes.csv to attributes.csv

# %%
 
attributes = pd.read_csv('attributes.csv', names = ['attributes'], delim_whitespace=True)
attributes
# Out:
#               attributes
# 0                  state
# 1                 county
# 2              community
# 3          communityname
# 4                   fold
# ..                   ...
# 123  LemasPctPolicOnPatr
# 124  LemasGangUnitDeploy
# 125  LemasPctOfficDrugUn
# 126      PolicBudgPerPop
# 127  ViolentCrimesPerPop
#
# [128 rows x 1 columns]

# %%
data = pd.read_csv('communities.data', names=attributes['attributes'],na_values=["?"])

# %%
data.head()
# Out:
#    state  county  ...  PolicBudgPerPop ViolentCrimesPerPop
# 0      8     NaN  ...             0.14                0.20
# 1     53     NaN  ...              NaN                0.67
# 2     24     NaN  ...              NaN                0.43
# 3     34     5.0  ...              NaN                0.12
# 4     42    95.0  ...              NaN                0.03
#
# [5 rows x 128 columns]

# %%
#enlever les attributs non prédictible
data = data.drop(columns=['state', 'county', 'community', 'communityname','fold'], axis = 1)
data.head()
# Out:
#    population  householdsize  ...  PolicBudgPerPop  ViolentCrimesPerPop
# 0        0.19           0.33  ...             0.14                 0.20
# 1        0.00           0.16  ...              NaN                 0.67
# 2        0.00           0.42  ...              NaN                 0.43
# 3        0.04           0.77  ...              NaN                 0.12
# 4        0.01           0.55  ...              NaN                 0.03
#
# [5 rows x 123 columns]

# %%
print(data.shape)
# Out:
# (1994, 123)

# %%
feat_miss = data.columns[data.isnull().any()]
print(feat_miss)
# Out:
# Index(['OtherPerCap', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps',
#        'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop',
#        'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol',
#        'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian',
#        'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz',
#        'PolicAveOTWorked', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr',
#        'LemasGangUnitDeploy', 'PolicBudgPerPop'],
#       dtype='object')

# %%
data[feat_miss].describe()
# Out:
#        OtherPerCap  LemasSwornFT  ...  LemasGangUnitDeploy  PolicBudgPerPop
# count  1993.000000    319.000000  ...           319.000000       319.000000
# mean      0.284742      0.069655  ...             0.440439         0.195078
# std       0.191008      0.138238  ...             0.405808         0.164718
# min       0.000000      0.000000  ...             0.000000         0.000000
# 25%       0.170000      0.010000  ...             0.000000         0.110000
# 50%       0.250000      0.020000  ...             0.500000         0.150000
# 75%       0.360000      0.060000  ...             1.000000         0.220000
# max       1.000000      1.000000  ...             1.000000         1.000000
#
# [8 rows x 23 columns]

# %%
data.fillna(data[['OtherPerCap']].mean(),inplace=True)

# %%
data[feat_miss].describe()
# Out:
#        OtherPerCap  LemasSwornFT  ...  LemasGangUnitDeploy  PolicBudgPerPop
# count  1994.000000    319.000000  ...           319.000000       319.000000
# mean      0.284742      0.069655  ...             0.440439         0.195078
# std       0.190960      0.138238  ...             0.405808         0.164718
# min       0.000000      0.000000  ...             0.000000         0.000000
# 25%       0.170000      0.010000  ...             0.000000         0.110000
# 50%       0.250000      0.020000  ...             0.500000         0.150000
# 75%       0.360000      0.060000  ...             1.000000         0.220000
# max       1.000000      1.000000  ...             1.000000         1.000000
#
# [8 rows x 23 columns]

# %%
print(feat_miss)
# Out:
# Index([], dtype='object')

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-304fa4ce4ebd> in <module>()
# ----> 1 data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
data.dropna(axis=1, inplace=True)
print(data.shape)
data.head()
# Out:
# (1994, 101)
#    population  householdsize  ...  LemasPctOfficDrugUn  ViolentCrimesPerPop
# 0        0.19           0.33  ...                 0.32                 0.20
# 1        0.00           0.16  ...                 0.00                 0.67
# 2        0.00           0.42  ...                 0.00                 0.43
# 3        0.04           0.77  ...                 0.00                 0.12
# 4        0.01           0.55  ...                 0.00                 0.03
#
# [5 rows x 101 columns]

# %%
data.describe()
# Out:
#         population  householdsize  ...  LemasPctOfficDrugUn  ViolentCrimesPerPop
# count  1994.000000    1994.000000  ...          1994.000000          1994.000000
# mean      0.057593       0.463395  ...             0.094052             0.237979
# std       0.126906       0.163717  ...             0.240328             0.232985
# min       0.000000       0.000000  ...             0.000000             0.000000
# 25%       0.010000       0.350000  ...             0.000000             0.070000
# 50%       0.020000       0.440000  ...             0.000000             0.150000
# 75%       0.050000       0.540000  ...             0.000000             0.330000
# max       1.000000       1.000000  ...             1.000000             1.000000
#
# [8 rows x 101 columns]

# %%
import matplotlib.pyplot as plt

data.hist(column=['ViolentCrimesPerPop'], bins = 100, color = 'green', alpha=0.9)
plt.show()

# %%
import seaborn as sns

corrmat = data.corr()
fig = plt.figure(figsize = (25, 16))

sns.heatmap(corrmat, vmax = 0.9)
plt.show()

# %%
corrT = data.corr(method = 'pearson').round(3)
corrT = corrT.sort_values(by=['ViolentCrimesPerPop'])
corrT['ViolentCrimesPerPop']
# Out:
# PctKids2Par           -0.738
# PctFam2Par            -0.707
# racePctWhite          -0.685
# PctYoungKids2Par      -0.666
# PctTeen2Par           -0.662
#                        ...
# FemalePctDiv           0.556
# pctWPubAsst            0.575
# racepctblack           0.631
# PctIlleg               0.738
# ViolentCrimesPerPop    1.000
# Name: ViolentCrimesPerPop, Length: 101, dtype: float64

# %%
import numpy as np

from sklearn.preprocessing import MinMaxScaler

# %%
X = data.iloc[:, 0:100].values
y = data.iloc[:, 100].values

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV


seed = 0

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = seed)

print(X.shape)
print(y.shape)
# Out:
# (1994, 100)
# (1994,)

# %%
from sklearn.preprocessing import StandardScaler

# Standardize features by removing the mean and scaling to unit variance

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor as rfr

model = rfr(n_estimators = 100)
model.fit(X_train,y_train)
score = model.score(X_test,y_test)

# %%
print(score)
# Out:
# 0.6295346616540667

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

# %%
y_pred = model.predict(X_test)

aerr = mae(y_pred,y_test)
print(aerr)

serr = mse(y_pred,y_test)
print(serr)

r2 = r2(y_pred,y_test)
print(r2)
# Out:
# 0.05425802292263609
# 0.007954536833810885
# 0.798428527015731

# %%
tr_score = []
ts_score = []
for j in range(100):

            X_train, X_test, y_train, y_test = train_test_split(X, y , random_state =j,     test_size=0.25)
            lr = rfr().fit(X_train, y_train)

            tr_score.append(lr.score(X_train, y_train))
            ts_score.append(lr.score(X_test, y_test))

J = ts_score.index(np.max(ts_score))

X_train, X_test, y_train, y_test = train_test_split(X, y , random_state =J, test_size=0.35)
M = rfr().fit(X_train, y_train)
y_pred = M.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
aerr = mae(y_pred,y_test)
print(aerr)

serr = mse(y_pred,y_test)
print(serr)
# Out:
# 0.05425802292263609
# 0.007954536833810885

# %%
print(J)
# Out:
# 9
